# %%
import os
import pandas as pd

# %%
DATA_LOC = '/root/xlcoder/MiniMind2-Small/dataset'

# %%
test_ratio = 0.2
random_seed = 42

# %%
df = pd.read_csv(os.path.join(DATA_LOC, "bbc-news-data.csv"), sep='\t')

train_parts = []
test_parts = []

for label, group in df.groupby("category"):
    # 随机打乱
    group = group.sample(frac=1, random_state=random_seed)
    
    # 计算测试集数量
    n_test = int(len(group) * test_ratio)
    
    # 划分
    test_part = group.iloc[:n_test]
    train_part = group.iloc[n_test:]
    
    test_parts.append(test_part)
    train_parts.append(train_part)

# 合并所有类别
train_df = pd.concat(train_parts).sample(frac=1, random_state=random_seed).reset_index(drop=True)
test_df  = pd.concat(test_parts).sample(frac=1, random_state=random_seed).reset_index(drop=True)

# 保存结果
train_df.to_csv(os.path.join(DATA_LOC, "bbc_train.csv"), index=False)
test_df.to_csv(os.path.join(DATA_LOC, "bbc_test.csv"), index=False)

print("训练集数量:", len(train_df))
print("测试集数量:", len(test_df))
print(train_df["category"].value_counts())
print(test_df["category"].value_counts())
# Out:
# 训练集数量: 1781
# 测试集数量: 444
# category
# sport            409
# business         408
# politics         334
# tech             321
# entertainment    309
# Name: count, dtype: int64
# category
# sport            102
# business         102
# politics          83
# tech              80
# entertainment     77
# Name: count, dtype: int64

# %%
df = pd.read_csv(os.path.join(DATA_LOC, "bbc_test.csv"))

# %%
replace_dict={
    "business": "<CLS_B>",
    "entertainment": "<CLS_E>",
    "politics": "<CLS_P>",
    "sport": "<CLS_S>",
    "tech": "<CLS_T>"
}
df['category'] = df['category'].replace(replace_dict)
df
# Out:
#     category filename                              title  \
# 0    <CLS_S>  132.txt   Republic to face China and Italy
# 1    <CLS_E>  166.txt   TV station refuses adoption show
# 2    <CLS_B>  019.txt    India widens access to telecoms
# 3    <CLS_T>  282.txt   Dublin hi-tech labs to shut down
# 4    <CLS_B>  281.txt   Axa Sun Life cuts bonus payments
# ..       ...      ...                                ...
# 439  <CLS_E>  151.txt   Eminem secret gig venue revealed
# 440  <CLS_S>  154.txt  Reyes tricked into Real admission
# 441  <CLS_S>  406.txt   Fuming Robinson blasts officials
# 442  <CLS_T>  141.txt    US top of supercomputing charts
# 443  <CLS_E>  337.txt   Career honour for actor DiCaprio
#
#                                                content
# 0     The Republic of Ireland have arranged friendl...
# 1     A TV station in the US has refused to show a ...
# 2     India has raised the limit for foreign direct...
# 3     Dublin's hi-tech research laboratory, Media L...
# 4     Life insurer Axa Sun Life has lowered annual ...
# ..                                                 ...
# 439   Rapper Eminem is to play an intimate gig in L...
# 440   Jose Antonio Reyes has added to speculation l...
# 441   England coach Andy Robinson said he was "livi...
# 442   The US has pushed Japan off the top of the su...
# 443   Actor Leonardo DiCaprio's "exceptional career...
#
# [444 rows x 4 columns]

# %%
df.to_csv(os.path.join(DATA_LOC, "bbc_test_std.csv"), index=False)
